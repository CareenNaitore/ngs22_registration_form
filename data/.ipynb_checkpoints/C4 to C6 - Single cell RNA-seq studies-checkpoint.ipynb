# %% [markdown]
# # C4 to C6 - Single cell RNA-seq studies
# Single-cell RNA sequencing (scRNA-seq) is arguably the most dramatically growing technology in both scale and use today.
# A curated database of scRNA-seq studies is available at https://www.nxn.se/single-cell-studies.
# Answer the following questions using the snapshot of data from https://github.com/NGSchoolEU/ngs22_registration_form/blob/1cc647a3733e2c8a21b47aa497b4ca8c42457aa8/data/single-cell-studies.tsv

# %%
# importing re library
import re
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('single-cell-studies.tsv',sep="\t")

# %%
data.head()
# Out:
#                 Shorthand                            DOI  \
# 0        Cauli et al PNAS        10.1073/pnas.97.11.6144
# 1       Malnic et al Cell  10.1016/S0092-8674(00)80581-4
# 2    Tietjen et al Neuron  10.1016/S0896-6273(03)00229-0
# 3  Gallopin et al CCortex          10.1093/cercor/bhj081
# 4      Kurimoto et al NAR             10.1093/nar/gkl050
#
#                                              Authors  \
# 0  B. Cauli, J. T. Porter, K. Tsuzuki, B. Lambole...
# 1  Bettina Malnic, Junzo Hirono, Takaaki Sato, Li...
# 2  Ian Tietjen, Jason M. Rihel, Yanxiang Cao, Geo...
# 3  Thierry Gallopin, Hélène Geoffroy, Jean Rossie...
# 4                                        K. Kurimoto
#
#                                            Journal  \
# 0  Proceedings of the National Academy of Sciences
# 1                                             Cell
# 2                                           Neuron
# 3                                  Cerebral Cortex
# 4                           Nucleic Acids Research
#
#                                                Title      Date bioRxiv DOI  \
# 0  Classification of fusiform neocortical interne...  20020726           -
# 1             Combinatorial Receptor Codes for Odors  20040410           -
# 2  Single-Cell Transcriptional Analysis of Neuron...  20040415           -
# 3  Cortical Sources of CRF, NKB, and CCK and Thei...  20051208           -
# 4  An improved single-cell cDNA amplification met...  20060330           -
#
#   Reported cells total      Organism Tissue  ...  \
# 0                   85           Rat  Brain  ...
# 1                   18         Mouse  Brain  ...
# 2                   37  Human, Mouse  Brain  ...
# 3                  157           Rat  Brain  ...
# 4                   20         Mouse    ICM  ...
#
#   Number of reported cell types or clusters Cell clustering Pseudotime  \
# 0                                       3.0             Yes         No
# 1                                       NaN             NaN        NaN
# 2                                       6.0             NaN        NaN
# 3                                       4.0             Yes         No
# 4                                       2.0             NaN        NaN
#
#   RNA Velocity  PCA tSNE H5AD location    Isolation  \
# 0           No  Yes   No           NaN  Patch-clamp
# 1          NaN  NaN  NaN           NaN          NaN
# 2          NaN  NaN  NaN           NaN  Manual, LCM
# 3           No  Yes   No           NaN  Patch-clamp
# 4          NaN  NaN  NaN           NaN          NaN
#
#    BC --> Cell ID _OR_ BC --> Cluster ID Number individuals
# 0                                    NaN                NaN
# 1                                    NaN                NaN
# 2                                    NaN                NaN
# 3                                    NaN                NaN
# 4                                    NaN                NaN
#
# [5 rows x 28 columns]

# %%
print(data.dtypes)
# Out:
# Shorthand                                     object
# DOI                                           object
# Authors                                       object
# Journal                                       object
# Title                                         object
# Date                                           int64
# bioRxiv DOI                                   object
# Reported cells total                          object
# Organism                                      object
# Tissue                                        object
# Technique                                     object
# Data location                                 object
# Panel size                                    object
# Measurement                                   object
# Cell source                                   object
# Disease                                       object
# Contrasts                                     object
# Developmental stage                           object
# Number of reported cell types or clusters    float64
# Cell clustering                               object
# Pseudotime                                    object
# RNA Velocity                                  object
# PCA                                           object
# tSNE                                          object
# H5AD location                                 object
# Isolation                                     object
# BC --> Cell ID _OR_ BC --> Cluster ID         object
# Number individuals                           float64
# dtype: object

# %%
# determines the number of items in the datasets
print(data.shape)
# Out:
# (1593, 28)

# %% [markdown]
# #### C4 - How many studies report data from more than one organism?

# %%
###Identifies the organisms that are more than one
## code to answer question C4 
df = data[data['Organism']== data['Organism'].str.extract(r'(.*,.*)', expand=False).str.strip()]
count=df['Organism'].value_counts()
print(count)
print(df.shape)
# Out:
# Human, Mouse                                                                     106
# Mouse, Human                                                                       9
# Human, Macaque                                                                     2
# Cynomolgus macaque, Human, Mouse, Pig, Rhesus macaque                              2
# Human, Zebrafish, Chicken, Marmoset, Sheep, Hamster, Mouse, Rat, Mole rat          1
# Human, Marmoset, Mouse                                                             1
# Human, Mouse, Macaque                                                              1
# Mouse, Rat                                                                         1
# Drosophila, Human                                                                  1
# Human, Rabbit                                                                      1
# Human, Macaque, Mouse                                                              1
# Bonobo, Chimpanzee, Human, Macaque                                                 1
# Human, Rat                                                                         1
# Human, Plasmodium                                                                  1
# Mouse, Human, Dog                                                                  1
# Cape cobra, Cape coral snake                                                       1
# Naked mole-rat, Mouse                                                              1
# Arabidopsis, Mouse                                                                 1
# Human, Frog                                                                        1
# Human, Macaque, Chimpanzee                                                         1
# Human, Zebrafish                                                                   1
# Human, Mouse, Pig                                                                  1
# Mouse, Rat, Human                                                                  1
# Chimpanzee, Human, Rhesus macaque                                                  1
# Bonobo, Chimpanzee, Human                                                          1
# Human, Rhesus, Rat, Mouse, Rabbit, Pig                                             1
# Lizard, Turtle                                                                     1
# Mouse, Zebrafish                                                                   1
# Drosophila, Human, Mouse                                                           1
# Human, Dog, Mouse                                                                  1
# Rat, Mouse                                                                         1
# Reticulitermes flavipes, Pyrsonympha vertens, Trichonympha agilis, Dinenympha      1
# Name: Organism, dtype: int64
# (147, 28)

# %% [markdown]
# #### C5 - After excluding the studies that report data from more than one organism, for which organism there are the most published studies, and how many?

# %%
#code to answer to question C5
#Identifies the number of organisms 
df2 = data[data['Organism']!= data['Organism'].str.extract(r'(.*,.*)', expand=False).str.strip()]
count = df2['Organism'].value_counts()
print(count)
# Out:
# Mouse                       632
# Human                       584
# Zebrafish                    35
# Drosophila                   15
# Rat                          12
# C elegans                     8
# Chicken                       5
# Arabidopsis thaliana          4
# Arabidopsis                   4
# Plasmodium                    3
# Yeast                         3
# Axolotl                       3
# Trypanosoma brucei            2
# Crab-eating macaque           2
# Ciona                         2
# Sea urchin                    2
# Xenopus                       2
# Macaque                       2
# Pig                           2
# Schmidtea mediterranea        2
# Planarian                     2
# Dictyostelium                 2
# Cynamolgus monkey             1
# Horse                         1
# Chlamydomonas                 1
# Bacillus subtilis             1
# Stony coral                   1
# Plasmodium falciparum         1
# Rabbit                        1
# Branchiostoma japonicum       1
# Marmoset                      1
# Rice                          1
# Pseudomonas aeruginosa        1
# Scallop                       1
# Caenorhabditis elegans        1
# Sponge                        1
# Clytia hemisphaerica          1
# Mouse lemur                   1
# Salmon                        1
# Plasmodium vivax              1
# Shrimp                        1
# Harpegnathos                  1
# Cow                           1
# Ciona intestinalis            1
# Sea Squirt                    1
# Saccharomyces cerevisiae      1
# Slime mold                    1
# Nematostella vectensis        1
# Frog                          1
# Ciona robusta                 1
# Ciona instestinalis           1
# Hydra                         1
# Plasmodium berghei            1
# Rhesus macaque                1
# Toxoplasma gondii             1
# Platynereis dumerilii         1
# Pogona vitticeps              1
# Toxoplasma                    1
# Honey bee                     1
# Hofstenia miamia              1
# Name: Organism, dtype: int64

# %% [markdown]
# #### C6 - After excluding the studies that report data from more than one organism, for which organism there are most reported cells, and how many?

# %%
#code to answer question 6
#number of cells in the organisms
count2 = df2[['Organism', 'Cell source']].value_counts()
print(count2)
# Out:
# Organism   Cell source
# Human      PBMCs                                             25
# Mouse      Microglia                                          9
# Human      Microglia                                          8
# Mouse      mESCs                                              8
# Human      Glioblastoma                                       8
#                                                              ..
#            Small cell lung cancer                             1
#            Sorted from PBMCs: DCs, monocytes, progenitors     1
#            Spermatogonial stem cells                          1
#            Subpallium (ganglionic eminances)                  1
# Zebrafish  cd41 cells from kidney and heart                   1
# Length: 627, dtype: int64
